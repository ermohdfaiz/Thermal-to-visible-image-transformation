jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05719.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05765.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05804.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05809.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05826.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05838.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05839.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05848.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05926.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05945.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05947.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05952.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05959.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_05974.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06001.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06024.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06035.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06061.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06105.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06107.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06141.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06151.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06154.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06197.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06216.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06230.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06246.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06251.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06252.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06267.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06282.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06283.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06286.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06311.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06327.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06329.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06338.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06345.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06354.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06359.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06362.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06381.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06427.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06473.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06504.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06538.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06546.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06592.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06635.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06686.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06719.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06727.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06814.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06821.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06873.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06879.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06902.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06948.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06951.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06963.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06978.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06980.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06986.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_06993.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07024.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07082.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07091.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07141.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07159.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07182.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07218.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07236.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07252.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07255.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07259.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07273.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07307.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07338.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07354.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07378.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07399.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07420.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07426.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07443.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07460.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07468.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07478.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07480.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07505.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07572.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07591.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07695.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07698.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07717.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07724.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07781.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07829.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07848.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07886.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07897.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07968.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07984.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_07992.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08039.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08091.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08099.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08145.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08158.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08165.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08214.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08216.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08220.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08246.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08290.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08337.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08343.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08357.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08363.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08423.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08430.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08456.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08474.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08486.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08501.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08513.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08546.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08561.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08584.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08623.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08688.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08689.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08715.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08744.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08746.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08783.jpeg
#   inflating: /content/data/new_dataset/thermal_8_bit/FLIR_08795.jpeg

# %%
# to get the files in proper order
def sorted_alphanumeric(data):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [convert(c) for c in re.split('([0-9]+)',key)]
    return sorted(data,key = alphanum_key)
# defining the size of the image
SIZE = 256
color_img = []
path = '/content/data/new_dataset/RGB'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):
        if i == 'FLIR_00200.jpg':
            break
        else:
            img = cv2.imread(path + '/'+i,1)
            # open cv reads images in BGR format so we have to convert it to RGB
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            #resizing image
            img = cv2.resize(img, (SIZE, SIZE))
            img = img.astype('float32') / 255.0
            color_img.append(img_to_array(img))


gray_img = []
path = '/content/data/new_dataset/thermal_8_bit'
files = os.listdir(path)
files = sorted_alphanumeric(files)
for i in tqdm(files):
         if i == 'FLIR_00200.jpeg':
            break
         else:
            img = cv2.imread(path + '/'+i,1)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            #resizing image
            img = cv2.resize(img, (SIZE, SIZE))
            img = img.astype('float32') / 255.0
            gray_img.append(img_to_array(img))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-76e0e1b977e8> in <cell line: 10>()
#       8 color_img = []
#       9 path = '/content/data/new_dataset/RGB'
# ---> 10 files = os.listdir(path)
#      11 files = sorted_alphanumeric(files)
#      12 for i in tqdm(files):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/data/new_dataset/RGB'

# %%
color_dataset=tf.data.Dataset.from_tensor_slices(np.array(color_img[:150])).batch(64)
gray_dataset=tf.data.Dataset.from_tensor_slices(np.array(gray_img[:150])).batch(64)

color_dataset_t=tf.data.Dataset.from_tensor_slices(np.array(color_img[150:])).batch(8)
gray_dataset_t=tf.data.Dataset.from_tensor_slices(np.array(gray_img[150:])).batch(8)

# %%
example_color = next(iter(color_dataset))
example_gray = next(iter(gray_dataset))

# %%
def plot_images(a = 4):

    for i in range(a):
        plt.figure(figsize = (10,10))
        plt.subplot(121)
        plt.title('color')
        plt.imshow(example_color[i] )

        plt.subplot(122)
        plt.title('gray')
        plt.imshow(example_gray[i])
        plt.show()

# %%
plot_images(2)

# %%
def downsample(filters, size, apply_batchnorm=True):

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer='he_normal', use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result

def upsample(filters, size, apply_dropout=False):


  result = tf.keras.Sequential()
  result.add(
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer='he_normal',
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result

# %%
def Generator():
  inputs = tf.keras.layers.Input(shape=[256,256,3])

  down_stack = [
    downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
    downsample(128, 4), # (bs, 64, 64, 128)
    downsample(256, 4), # (bs, 32, 32, 256)
    downsample(512, 4), # (bs, 16, 16, 512)
    downsample(512, 4), # (bs, 8, 8, 512)
    downsample(512, 4), # (bs, 4, 4, 512)
    downsample(512, 4), # (bs, 2, 2, 512)
    downsample(512, 4), # (bs, 1, 1, 512)
  ]

  up_stack = [
    upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
    upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
    upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
    upsample(512, 4), # (bs, 16, 16, 1024)
    upsample(256, 4), # (bs, 32, 32, 512)
    upsample(128, 4), # (bs, 64, 64, 256)
    upsample(64, 4), # (bs, 128, 128, 128)
  ]

  initializer = tf.random_normal_initializer(0., 0.02)
  last = tf.keras.layers.Conv2DTranspose(3, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh') # (bs, 256, 256, 3)

  x = inputs

  # Downsampling through the model
  skips = []
  for down in down_stack:
    x = down(x)
    skips.append(x)

  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    x = tf.keras.layers.Concatenate()([x, skip])

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
def Discriminator():
  initializer = tf.random_normal_initializer(0., 0.02)

  inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
  tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

  x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

  down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
  down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
  down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

  zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
  conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

  batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

  leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

  zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

  last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

  return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
generator = Generator()
generator.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  sequential_18 (Sequential)     (None, 128, 128, 64  3072        ['input_2[0][0]']
#                                 )
#
#  sequential_19 (Sequential)     (None, 64, 64, 128)  131584      ['sequential_18[0][0]']
#
#  sequential_20 (Sequential)     (None, 32, 32, 256)  525312      ['sequential_19[0][0]']
#
#  sequential_21 (Sequential)     (None, 16, 16, 512)  2099200     ['sequential_20[0][0]']
#
#  sequential_22 (Sequential)     (None, 8, 8, 512)    4196352     ['sequential_21[0][0]']
#
#  sequential_23 (Sequential)     (None, 4, 4, 512)    4196352     ['sequential_22[0][0]']
#
#  sequential_24 (Sequential)     (None, 2, 2, 512)    4196352     ['sequential_23[0][0]']
#
#  sequential_25 (Sequential)     (None, 1, 1, 512)    4196352     ['sequential_24[0][0]']
#
#  sequential_26 (Sequential)     (None, 2, 2, 512)    4196352     ['sequential_25[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 2, 2, 1024)   0           ['sequential_26[0][0]',
#                                                                   'sequential_24[0][0]']
#
#  sequential_27 (Sequential)     (None, 4, 4, 512)    8390656     ['concatenate_8[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 4, 4, 1024)   0           ['sequential_27[0][0]',
#                                                                   'sequential_23[0][0]']
#
#  sequential_28 (Sequential)     (None, 8, 8, 512)    8390656     ['concatenate_9[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 8, 8, 1024)   0           ['sequential_28[0][0]',
#                                                                   'sequential_22[0][0]']
#
#  sequential_29 (Sequential)     (None, 16, 16, 512)  8390656     ['concatenate_10[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 16, 16, 1024  0           ['sequential_29[0][0]',
#                                 )                                 'sequential_21[0][0]']
#
#  sequential_30 (Sequential)     (None, 32, 32, 256)  4195328     ['concatenate_11[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 512)  0           ['sequential_30[0][0]',
#                                                                   'sequential_20[0][0]']
#
#  sequential_31 (Sequential)     (None, 64, 64, 128)  1049088     ['concatenate_12[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 256)  0           ['sequential_31[0][0]',
#                                                                   'sequential_19[0][0]']
#
#  sequential_32 (Sequential)     (None, 128, 128, 64  262400      ['concatenate_13[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 128, 128, 12  0           ['sequential_32[0][0]',
#                                 8)                                'sequential_18[0][0]']
#
#  conv2d_transpose_15 (Conv2DTra  (None, 256, 256, 3)  6147       ['concatenate_14[0][0]']
#  nspose)
#
# ==================================================================================================
# Total params: 54,425,859
# Trainable params: 54,414,979
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
discriminator = Discriminator()
discriminator.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_image (InputLayer)       [(None, 256, 256, 3  0           []
#                                 )]
#
#  target_image (InputLayer)      [(None, 256, 256, 3  0           []
#                                 )]
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 6)  0           ['input_image[0][0]',
#                                                                   'target_image[0][0]']
#
#  sequential_33 (Sequential)     (None, 128, 128, 64  6144        ['concatenate_15[0][0]']
#                                 )
#
#  sequential_34 (Sequential)     (None, 64, 64, 128)  131584      ['sequential_33[0][0]']
#
#  sequential_35 (Sequential)     (None, 32, 32, 256)  525312      ['sequential_34[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 34, 34, 256)  0          ['sequential_35[0][0]']
#  D)
#
#  conv2d_24 (Conv2D)             (None, 31, 31, 512)  2097152     ['zero_padding2d_2[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 31, 31, 512)  2048       ['conv2d_24[0][0]']
#  ormalization)
#
#  leaky_re_lu_23 (LeakyReLU)     (None, 31, 31, 512)  0           ['batch_normalization_33[0][0]']
#
#  zero_padding2d_3 (ZeroPadding2  (None, 33, 33, 512)  0          ['leaky_re_lu_23[0][0]']
#  D)
#
#  conv2d_25 (Conv2D)             (None, 30, 30, 1)    8193        ['zero_padding2d_3[0][0]']
#
# ==================================================================================================
# Total params: 2,770,433
# Trainable params: 2,768,641
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

LAMBDA = 100

def generator_loss(disc_generated_output, gen_output, target):
  gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

  # mean absolute error
  l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

  total_gen_loss = gan_loss + (LAMBDA * l1_loss)

  return total_gen_loss, gan_loss, l1_loss

def discriminator_loss(disc_real_output, disc_generated_output):
  real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

  generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss

# %%
def train_step(input_image, target, epoch):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = generator(input_image, training=True)

    disc_real_output = discriminator([input_image, target], training=True)
    disc_generated_output = discriminator([input_image, gen_output], training=True)

    gen_total_loss, gen_gan_loss, gen_l1_loss = generator_loss(disc_generated_output, gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_total_loss,
                                          generator.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))

# %%
import time
def fit(train_ds, epochs,):
  for epoch in range(epochs):
    start = time.time()

    print("Epoch: ", epoch+1)

    # Train
    for n, (input_image, target) in train_ds.enumerate():

      train_step(input_image, target, epoch)
    print()



    print ('Time taken for epoch {} is {} sec\n'.format(epoch + 1,
                                                        time.time()-start))

# %%
def generate_images(model, test_input, tar):
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15,15))

  display_list = [test_input[0], tar[0], prediction[0]]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # getting the pixel values between [0, 1] to plot it.
    plt.imshow(display_list[i])
    plt.axis('off')
  plt.show()

for example_input, example_target in tf.data.Dataset.zip((gray_dataset,color_dataset)).take(2):
  generate_images(generator, example_input, example_target)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
fit(tf.data.Dataset.zip((gray_dataset, color_dataset)),epochs = 5)
# Out:
# Epoch:  1
#
# Time taken for epoch 1 is 502.23604559898376 sec
#
# Epoch:  2
#
# Time taken for epoch 2 is 502.1013617515564 sec
#
# Epoch:  3
#
# Time taken for epoch 3 is 502.0440204143524 sec
#
# Epoch:  4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-daebb1c09257> in <cell line: 1>()
# ----> 1 fit(tf.data.Dataset.zip((gray_dataset, color_dataset)),epochs = 10)
#
# <ipython-input-30-5da6ee905b6e> in fit(train_ds, epochs)
#       9     for n, (input_image, target) in train_ds.enumerate():
#      10
# ---> 11       train_step(input_image, target, epoch)
#      12     print()
#      13
#
# <ipython-input-29-9f1e81ba5a91> in train_step(input_image, target, epoch)
#      11   generator_gradients = gen_tape.gradient(gen_total_loss,
#      12                                           generator.trainable_variables)
# ---> 13   discriminator_gradients = disc_tape.gradient(disc_loss,
#      14                                                discriminator.trainable_variables)
#      15
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1061                           for x in output_gradients]
#    1062
# -> 1063     flat_grad = imperative_grad.imperative_grad(
#    1064         self._tape,
#    1065         flat_targets,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      65         "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
#      66
# ---> 67   return pywrap_tfe.TFE_Py_TapeGradient(
#      68       tape._tape,  # pylint: disable=protected-access
#      69       target,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     144       gradient_name_scope += forward_pass_name_scope + "/"
#     145     with ops.name_scope(gradient_name_scope):
# --> 146       return grad_fn(mock_op, *out_grads)
#     147   else:
#     148     return grad_fn(mock_op, *out_grads)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/nn_grad.py in _Conv2DGrad(op, grad)
#     580   # in Eager mode.
#     581   return [
# --> 582       gen_nn_ops.conv2d_backprop_input(
#     583           shape_0,
#     584           op.inputs[1],
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/ops/gen_nn_ops.py in conv2d_backprop_input(input_sizes, filter, out_backprop, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1617   if tld.is_eager:
#    1618     try:
# -> 1619       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1620         _ctx, "Conv2DBackpropInput", name, input_sizes, filter, out_backprop,
#    1621         "strides", strides, "use_cudnn_on_gpu", use_cudnn_on_gpu, "padding",
#
# KeyboardInterrupt:

# %%
def generate_images(model, test_input, tar):
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15,15))

  display_list = [test_input[0], tar[0], prediction[0]]
  title = ['Input Image', 'Ground Truth', 'Predicted Image']

  for i in range(3):
    plt.subplot(1, 3, i+1)
    plt.title(title[i])
    # getting the pixel values between [0, 1] to plot it.
    plt.imshow(display_list[i])
    plt.axis('off')
  plt.show()

for example_input, example_target in tf.data.Dataset.zip((gray_dataset_t,color_dataset_t)).take(3):
  generate_images(generator, example_input, example_target)
